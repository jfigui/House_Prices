# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.max_columns= 82
pd.options.display.max_rows=82

# %% [markdown]
# # Data cleaning

# %%
df_tr = pd.read_csv('house-prices.csv')
print(df_tr.shape)
df_tr.head()
# Out:
# (2430, 82)
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    484  528275070           60        RL           NaN      8795   Pave
# 1   2586  535305120           20        RL          75.0     10170   Pave
# 2   2289  923228250          160        RM          21.0      2001   Pave
# 3    142  535152150           20        RL          70.0     10552   Pave
# 4   2042  903475060          190        RM          60.0     10120   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 1   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 2   NaN       Reg          Lvl    AllPub     Inside        Gtl      MeadowV
# 3   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
# 4   NaN       IR1          Bnk    AllPub     Inside        Gtl      OldTown
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      2Story             7             5
# 1        Norm        Norm      1Fam      1Story             6             6
# 2        Norm        Norm     Twnhs      2Story             4             5
# 3        Norm        Norm      1Fam      1Story             5             5
# 4       Feedr        Norm    2fmCon      2.5Unf             7             4
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        2000            2000      Gable   CompShg      VinylSd      VinylSd
# 1        1951            1951        Hip   CompShg      Wd Sdng      Wd Sdng
# 2        1970            1970      Gable   CompShg      CemntBd      CmentBd
# 3        1959            1959        Hip   CompShg      BrkFace      BrkFace
# 4        1910            1950        Hip   CompShg      Wd Sdng      Wd Sdng
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         Gd         TA      PConc        Gd
# 1      BrkFace         522.0         TA         TA     CBlock        TA
# 2      BrkFace          80.0         TA         TA     CBlock        TA
# 3         None           0.0         TA         TA     CBlock        TA
# 4         None           0.0         Fa         TA     CBlock        TA
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         300.0            Unf
# 1        TA            No            Unf           0.0            Unf
# 2        TA            No            Unf           0.0            Unf
# 3        TA            No            Rec        1018.0            Unf
# 4        TA            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        652.0          952.0    GasA         Ex           Y
# 1           0.0        216.0          216.0    GasA         TA           Y
# 2           0.0        546.0          546.0    GasA         Fa           Y
# 3           0.0        380.0         1398.0    GasA         Gd           Y
# 4           0.0        925.0          925.0    GasA         TA           N
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         980        1276                0         2256
# 1      SBrkr        1575           0                0         1575
# 2      SBrkr         546         546                0         1092
# 3      SBrkr        1700           0                0         1700
# 4      FuseF         964         925                0         1889
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              4
# 1             0.0             0.0          1          1              2
# 2             0.0             0.0          1          1              3
# 3             0.0             1.0          1          1              4
# 4             0.0             0.0          1          1              4
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              8        Typ           1
# 1              1           Gd              5        Typ           1
# 2              1           TA              6        Typ           0
# 3              1           Gd              6        Typ           1
# 4              2           TA              9        Typ           1
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           TA     BuiltIn         2000.0           Fin          2.0
# 1           Gd      Attchd         1951.0           Unf          2.0
# 2          NaN      Attchd         1970.0           Unf          1.0
# 3           Gd      Attchd         1959.0           RFn          2.0
# 4           Gd      Detchd         1960.0           Unf          1.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        554.0          TA          TA           Y           224
# 1        400.0          TA          TA           Y             0
# 2        286.0          TA          TA           Y             0
# 3        447.0          TA          TA           Y             0
# 4        308.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             54               0           0             0          0     NaN
# 1              0               0           0             0          0     NaN
# 2              0               0           0             0          0     NaN
# 3             38               0           0             0          0     NaN
# 4              0             264           0             0          0     NaN
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  \
# 0    NaN          NaN         0        4     2009       WD          Normal
# 1    NaN          NaN         0        6     2006       WD          Normal
# 2    NaN          NaN         0        1     2007       WD          Normal
# 3    NaN          NaN         0        4     2010       WD          Normal
# 4  MnPrv          NaN         0        1     2007       WD          Normal
#
#    SalePrice
# 0     236000
# 1     155000
# 2      75000
# 3     165500
# 4     122000

# %%
df_te = pd.read_csv('house-prices-test.csv')
print(df_te.shape)
df_te.head()
# Out:
# (500, 81)
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   2217  909279080           50        RL           NaN     11275   Pave
# 1    837  907126050           20        RL          65.0      9757   Pave
# 2   2397  528144030           60        RL          86.0     11065   Pave
# 3   1963  535452060           20        RL          70.0      7000   Pave
# 4    306  911202100           50   C (all)          66.0      8712   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          HLS    AllPub     Corner        Mod      Crawfor
# 1   NaN       Reg          Low    AllPub     Inside        Mod      CollgCr
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      NridgHt
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 4  Pave       Reg          HLS    AllPub     Inside        Mod       IDOTRR
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1.5Fin             6             7
# 1        Norm        Norm      1Fam      1Story             5             7
# 2        Norm        Norm      1Fam      2Story             8             5
# 3        Norm        Norm      1Fam      1Story             5             7
# 4        Norm        Norm      1Fam      1.5Fin             4             7
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1932            1950      Gable   CompShg      MetalSd      MetalSd
# 1        1994            1994      Gable   CompShg      VinylSd      VinylSd
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1960            2002      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1900            1950      Gable   CompShg      MetalSd      MetalSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         480.0         TA         TA     CBlock        TA
# 1         None           0.0         TA         Gd      PConc        TA
# 2        Stone         788.0         Gd         TA      PConc        Gd
# 3      BrkFace          45.0         TA         TA     CBlock        TA
# 4         None           0.0         TA         TA      Stone        TA
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            Mn            Rec         297.0            LwQ
# 1        TA            No            ALQ         755.0            Unf
# 2        TA            Mn            Unf           0.0            Unf
# 3        TA            No            Rec         588.0            Unf
# 4        TA            Mn            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0         557.0          0.0          854.0    GasA         TA           Y
# 1           0.0        235.0          990.0    GasA         Ex           Y
# 2           0.0       1085.0         1085.0    GasA         Ex           Y
# 3           0.0        422.0         1010.0    GasA         Ex           Y
# 4           0.0        859.0          859.0    GasA         Gd           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1096         895                0         1991
# 1      SBrkr         990           0                0          990
# 2      SBrkr        1120         850                0         1970
# 3      SBrkr        1134           0                0         1134
# 4      SBrkr         859         319                0         1178
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          1          1              3
# 1             1.0             0.0          1          0              3
# 2             0.0             0.0          2          1              3
# 3             0.0             0.0          1          0              2
# 4             0.0             0.0          1          0              2
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           TA              7        Typ           1
# 1              1           TA              5        Typ           0
# 2              1           Ex              8        Typ           1
# 3              1           TA              6        Typ           0
# 4              1           TA              7        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           Gd      Detchd         1977.0           Unf          2.0
# 1          NaN      Attchd         1995.0           RFn          1.0
# 2           Gd     BuiltIn         2006.0           Fin          3.0
# 3          NaN      Attchd         1960.0           RFn          1.0
# 4          NaN      Detchd         1964.0           RFn          1.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        432.0          TA          Fa           Y             0
# 1        440.0          TA          TA           Y            66
# 2        753.0          TA          TA           Y           177
# 3        254.0          TA          TA           Y             0
# 4        384.0          TA          TA           N            68
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0              0              19           0             0          0     NaN
# 1              0               0           0            92          0     NaN
# 2             74               0           0             0          0     NaN
# 3             16               0           0             0          0     NaN
# 4              0              98           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition
# 0   NaN          NaN         0        3     2007       WD          Normal
# 1   NaN          NaN         0       10     2009       WD          Normal
# 2   NaN          NaN         0       10     2006       New        Partial
# 3  MnWw          NaN         0        4     2007       WD          Family
# 4   NaN          NaN         0        1     2010       WD         Abnorml

# %%
# Concatenate training and test for clean up
df_te['SalePrice'] = np.NaN
df = pd.concat([df_tr, df_te], ignore_index=True)
df.tail()
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2925    235  905378040           50        RL         124.0     18600   Pave
# 2926   2518  533252020           20        RL           NaN     11250   Pave
# 2927    350  527127100          120        RL          28.0      7296   Pave
# 2928    821  906340120           20        RL          61.0     10226   Pave
# 2929   2005  902427180           80        RM          76.0     11800   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 2925   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2926   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2927   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2928   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2929   NaN       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 2925      Edwards        Norm        Norm      1Fam      1.5Fin             3
# 2926      Veenker        Norm        Norm      1Fam      1Story             6
# 2927      StoneBr        Norm        Norm    TwnhsE      1Story             8
# 2928      CollgCr        Norm        Norm      1Fam      1Story             8
# 2929      OldTown        Norm        Norm      1Fam        SLvl             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 2925             4        1938            1990      Gable   CompShg
# 2926             6        1977            1977      Gable   CompShg
# 2927             5        2004            2005      Gable   CompShg
# 2928             5        2008            2008      Gable   CompShg
# 2929             7        1949            2002      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 2925      Wd Sdng      Wd Sdng         None           0.0         TA
# 2926      Plywood      Plywood         None           0.0         Gd
# 2927      CemntBd      CmentBd         None           0.0         Gd
# 2928      VinylSd      VinylSd        Stone         270.0         Gd
# 2929       Stucco      Wd Sdng         None           0.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 2925         TA     CBlock        TA        TA            Mn            BLQ
# 2926         TA     CBlock        Gd        TA            No            ALQ
# 2927         TA      PConc        Ex        TA            Av            GLQ
# 2928         TA      PConc        Ex        TA            Gd            Unf
# 2929         TA       Slab       NaN       NaN           NaN            NaN
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 2925         288.0            LwQ         684.0          0.0          972.0
# 2926         767.0            Unf           0.0        441.0         1208.0
# 2927        1965.0            Unf           0.0        243.0         2208.0
# 2928           0.0            Unf           0.0       1622.0         1622.0
# 2929           0.0            NaN           0.0          0.0            0.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 2925    GasA         TA           Y      FuseA        1052         558
# 2926    GasA         TA           Y      SBrkr        1208           0
# 2927    GasA         Ex           Y      SBrkr        2522           0
# 2928    GasA         Ex           Y      SBrkr        1630           0
# 2929    GasA         Ex           Y      SBrkr        1382           0
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 2925                0         1610             0.0             1.0          2
# 2926                0         1208             1.0             0.0          1
# 2927                0         2522             1.0             0.0          2
# 2928                0         1630             1.0             0.0          2
# 2929                0         1382             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 2925          0              4              1           Fa              8
# 2926          1              3              1           TA              6
# 2927          0              1              1           Gd              8
# 2928          0              3              1           Ex              8
# 2929          0              1              1           TA              6
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 2925        Typ           1           Gd      Attchd         1938.0
# 2926        Typ           1           TA      Attchd         1977.0
# 2927        Typ           1           Gd      Attchd         2004.0
# 2928        Typ           1           Gd      Attchd         2008.0
# 2929        Mod           1           TA      Attchd         1957.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 2925           RFn          1.0        480.0          TA          TA
# 2926           RFn          2.0        546.0          TA          TA
# 2927           Fin          2.0        564.0          TA          TA
# 2928           RFn          3.0        860.0          TA          TA
# 2929           RFn          1.0        384.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 2925           Y             0              0              60           0
# 2926           Y           198             42               0           0
# 2927           Y           182             57               0           0
# 2928           Y           172             42               0           0
# 2929           Y             0             40               0           0
#
#       Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 2925             0          0     NaN   NaN         Shed       450        6
# 2926             0          0     NaN   NaN          NaN         0        6
# 2927             0          0     NaN   NaN          NaN         0       11
# 2928             0          0     NaN   NaN          NaN         0        1
# 2929             0          0     NaN   NaN          NaN         0        5
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 2925     2010       WD          Normal        NaN
# 2926     2006       WD          Normal        NaN
# 2927     2009       WD          Normal        NaN
# 2928     2009       WD          Normal        NaN
# 2929     2007       WD          Normal        NaN

# %% [markdown]
# ## General overview of the data

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'Sale Condition', 'SalePrice'],
#       dtype='object')

# %%
# columns with nominal values (23 + PID)
nominal_cols = [
    'PID', 'MS SubClass', 'MS Zoning', 'Street', 'Alley', 'Land Contour',
    'Lot Config', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style',
    'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation',
    'Heating', 'Central Air', 'Garage Type', 'Misc Feature', 'Sale Type', 'Sale Condition']

# columns with ordinal values (23)
ordinal_cols = [
    'Lot Shape', 'Utilities', 'Land Slope', 'Overall Qual', 'Overall Cond', 'Exter Qual',
    'Exter Cond', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2',
    'Heating QC', 'Electrical', 'Kitchen Qual', 'Functional', 'Fireplace Qu', 'Garage Finish',
    'Garage Qual', 'Garage Cond', 'Paved Drive','Pool QC', 'Fence']

# columns with discrete values (14 + Order)
discrete_cols = [
    'Order', 'Year Built', 'Year Remod/Add', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
    'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces', 'Garage Yr Blt',
    'Garage Cars', 'Mo Sold', 'Yr Sold']

# Continuous cols (20 including SalePrice)
continuous_cols = [
    'Lot Frontage', 'Lot Area', 'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF',
    'Total Bsmt SF', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Garage Area',
    'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area',
    'Misc Val','SalePrice']

# %%
df[continuous_cols].hist(figsize=(20, 20), bins=50)
plt.show()

# %%
df[discrete_cols].hist(figsize=(20, 20), bins=50)
plt.show()

# %%
df[nominal_cols].isna().sum()
# Out:
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Street               0
# Alley             2732
# Land Contour         0
# Lot Config           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type        23
# Foundation           0
# Heating              0
# Central Air          0
# Garage Type        157
# Misc Feature      2824
# Sale Type            0
# Sale Condition       0
# dtype: int64

# %%
df[nominal_cols].dtypes
# Out:
# PID                int64
# MS SubClass        int64
# MS Zoning         object
# Street            object
# Alley             object
# Land Contour      object
# Lot Config        object
# Neighborhood      object
# Condition 1       object
# Condition 2       object
# Bldg Type         object
# House Style       object
# Roof Style        object
# Roof Matl         object
# Exterior 1st      object
# Exterior 2nd      object
# Mas Vnr Type      object
# Foundation        object
# Heating           object
# Central Air       object
# Garage Type       object
# Misc Feature      object
# Sale Type         object
# Sale Condition    object
# dtype: object

# %%
df['MS SubClass'] = df['MS SubClass'].astype(str)
df[nominal_cols].dtypes
# Out:
# PID                int64
# MS SubClass       object
# MS Zoning         object
# Street            object
# Alley             object
# Land Contour      object
# Lot Config        object
# Neighborhood      object
# Condition 1       object
# Condition 2       object
# Bldg Type         object
# House Style       object
# Roof Style        object
# Roof Matl         object
# Exterior 1st      object
# Exterior 2nd      object
# Mas Vnr Type      object
# Foundation        object
# Heating           object
# Central Air       object
# Garage Type       object
# Misc Feature      object
# Sale Type         object
# Sale Condition    object
# dtype: object

# %%
fig, axes = plt.subplots(nrows=6, ncols=4, figsize=(20,20))
for i, col in enumerate(nominal_cols[1:]):
    df[col].value_counts().plot(kind='barh', ax=axes[int(i/4), i%4], title=col)
plt.show()

# %%
df[ordinal_cols].dtypes
# Out:
# Lot Shape         object
# Utilities         object
# Land Slope        object
# Overall Qual       int64
# Overall Cond       int64
# Exter Qual        object
# Exter Cond        object
# Bsmt Qual         object
# Bsmt Cond         object
# Bsmt Exposure     object
# BsmtFin Type 1    object
# BsmtFin Type 2    object
# Heating QC        object
# Electrical        object
# Kitchen Qual      object
# Functional        object
# Fireplace Qu      object
# Garage Finish     object
# Garage Qual       object
# Garage Cond       object
# Paved Drive       object
# Pool QC           object
# Fence             object
# dtype: object

# %%
df[ordinal_cols].isna().sum()
# Out:
# Lot Shape            0
# Utilities            0
# Land Slope           0
# Overall Qual         0
# Overall Cond         0
# Exter Qual           0
# Exter Cond           0
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin Type 2      81
# Heating QC           0
# Electrical           1
# Kitchen Qual         0
# Functional           0
# Fireplace Qu      1422
# Garage Finish      159
# Garage Qual        159
# Garage Cond        159
# Paved Drive          0
# Pool QC           2917
# Fence             2358
# dtype: int64

# %%
df['Overall Qual'] = df['Overall Qual'].astype(str)
df['Overall Cond'] = df['Overall Cond'].astype(str)
df[ordinal_cols].dtypes
# Out:
# Lot Shape         object
# Utilities         object
# Land Slope        object
# Overall Qual      object
# Overall Cond      object
# Exter Qual        object
# Exter Cond        object
# Bsmt Qual         object
# Bsmt Cond         object
# Bsmt Exposure     object
# BsmtFin Type 1    object
# BsmtFin Type 2    object
# Heating QC        object
# Electrical        object
# Kitchen Qual      object
# Functional        object
# Fireplace Qu      object
# Garage Finish     object
# Garage Qual       object
# Garage Cond       object
# Paved Drive       object
# Pool QC           object
# Fence             object
# dtype: object

# %%
fig, axes = plt.subplots(nrows=6, ncols=4, figsize=(20,20))
for i, col in enumerate(ordinal_cols):
    df[col].value_counts().plot(kind='barh', ax=axes[int(i/4), i%4], title=col)
plt.show()

# %% [markdown]
# ## Fix nominal columns

# %%
nominal_ser_na = df[nominal_cols].isna().sum()
nominal_ser_na[nominal_ser_na>0]
# Out:
# Alley           2732
# Mas Vnr Type      23
# Garage Type      157
# Misc Feature    2824
# dtype: int64

# %%
# All NaN are category NA except Mas Vnr Type where None category exists
ind_nominal_na = nominal_ser_na[nominal_ser_na > 0].index
df['Mas Vnr Type'] = df['Mas Vnr Type'].fillna('Missing')
df[ind_nominal_na] = df[ind_nominal_na].fillna('NA')
df['Mas Vnr Type'] = df['Mas Vnr Type'].astype(str)

# %% [markdown]
# ## Fix ordinal columns

# %%
ordinal_ser_na = df[ordinal_cols].isna().sum()
ordinal_ser_na[ordinal_ser_na > 0]
# Out:
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin Type 2      81
# Electrical           1
# Fireplace Qu      1422
# Garage Finish      159
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# dtype: int64

# %%
# All NaN are category NA except Electrical
ind_ordinal_na = ordinal_ser_na[ordinal_ser_na > 0].index
df['Electrical'] = df['Electrical'].fillna('Missing')
df[ind_ordinal_na] = df[ind_ordinal_na].fillna('NA')
df[ind_ordinal_na] = df[ind_ordinal_na].astype(str)

# %% [markdown]
# ## Fix discrete columns

# %%
discrete_ser_na = df[discrete_cols].isna().sum()
discrete_ser_na[discrete_ser_na > 0]
# Out:
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Garage Yr Blt     159
# Garage Cars         1
# dtype: int64

# %%
df[df['Bsmt Full Bath'].isna()]
# Out:
#       Order        PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 104    1342  903230120          20        RM          99.0      5940   Pave
# 2056   1498  908154080          20        RL         123.0     47007   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 104     NA       IR1          Lvl    AllPub        FR3        Gtl
# 2056    NA       IR1          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style Overall Qual  \
# 104       BrkSide       Feedr        Norm      1Fam      1Story            4
# 2056      Edwards        Norm        Norm      1Fam      1Story            5
#
#      Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 104             7        1946            1950      Gable   CompShg
# 2056            7        1959            1996      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 104       MetalSd       CBlock         None           0.0         TA
# 2056      Plywood      Plywood         None           0.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 104          TA      PConc        NA        NA            NA             NA
# 2056         TA       Slab        NA        NA            NA             NA
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 104            NaN             NA           NaN          NaN            NaN
# 2056           0.0             NA           0.0          0.0            0.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 104     GasA         TA           Y      FuseA         896           0
# 2056    GasA         TA           Y      SBrkr        3820           0
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 104                 0          896             NaN             NaN          1
# 2056                0         3820             NaN             NaN          3
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 104           0              2              1           TA              4
# 2056          1              5              1           Ex             11
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 104         Typ           0           NA      Detchd         1946.0
# 2056        Typ           2           Gd      Attchd         1959.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 104            Unf          1.0        280.0          TA          TA
# 2056           Unf          2.0        624.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 104            Y             0              0               0           0
# 2056           Y             0            372               0           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 104              0          0      NA  MnPrv           NA         0        4
# 2056             0          0      NA     NA           NA         0        7
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 104      2008     ConLD        Abnorml    79000.0
# 2056     2008       WD          Normal   284700.0

# %%
# Assume number of basement baths equal number of baths
ind_bath_na = df[df['Bsmt Full Bath'].isna()].index
df.loc[ind_bath_na, 'Bsmt Full Bath'] = df.loc[ind_bath_na, 'Full Bath']
df.loc[ind_bath_na, 'Bsmt Half Bath'] = df.loc[ind_bath_na, 'Half Bath']

# %%
df[df['Garage Cars'].isna()]
# Out:
#       Order        PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1565   2237  910201180          70        RM          50.0      9060   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1565    NA       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style Overall Qual  \
# 1565       IDOTRR        Norm        Norm      1Fam      2Story            5
#
#      Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1565            6        1923            1999      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1565      Wd Sdng      Plywood         None           0.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 1565         TA     BrkTil        Gd        TA            No            ALQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 1565         548.0            Unf           0.0        311.0          859.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 1565    GasA         Ex           Y      SBrkr         942         886
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 1565                0         1828             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 1565          0              3              1           Gd              6
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 1565        Typ           0           NA      Detchd            NaN
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 1565            NA          NaN          NaN          NA          NA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 1565           Y           174              0             212           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 1565             0          0      NA  MnPrv           NA         0        3
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 1565     2007       WD          Alloca   150909.0

# %%
# Assume there was no garage
ind_cars_na = df[df['Garage Cars'].isna()].index
df.loc[ind_cars_na, 'Garage Type'] = 'NA'
df.loc[ind_cars_na, 'Garage Cars'] = 0
df.loc[ind_cars_na, 'Garage Area'] = 0.0

# %%
# Check data for year built above 2010
df[df['Garage Yr Blt'] > 2010]
# Out:
#       Order        PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2219   2261  916384070          20        RL          68.0      8298   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 2219    NA       IR1          HLS    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style Overall Qual  \
# 2219       Timber        Norm        Norm      1Fam      1Story            8
#
#      Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 2219            5        2006            2007        Hip   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 2219      VinylSd      VinylSd      Missing           NaN         Gd
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 2219         TA      PConc        Gd        TA            Av            GLQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 2219         583.0            Unf           0.0        963.0         1546.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 2219    GasA         Ex           Y      SBrkr        1564           0
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 2219                0         1564             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 2219          0              2              1           Ex              6
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 2219        Typ           1           Gd      Attchd         2207.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 2219           RFn          2.0        502.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 2219           Y           132              0               0           0
#
#       Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 2219             0          0      NA    NA           NA         0        9
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 2219     2007       New        Partial   267300.0

# %%
# Assumed built at the same time of house
ind_garage = df[df['Garage Yr Blt'] > 2010].index
df.loc[ind_garage, 'Garage Yr Blt'] = df.loc[ind_garage, 'Year Built']

# %%
df[df['Year Built'] > df['Year Remod/Add']]
# Out:
#       Order        PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2612    851  907194160          20        RL          65.0     10739   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 2612    NA       IR1          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style Overall Qual  \
# 2612      CollgCr        Norm        Norm      1Fam      1Story            7
#
#      Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 2612            5        2002            2001      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 2612      VinylSd      VinylSd      BrkFace          68.0         Gd
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 2612         TA      PConc        Gd        TA            No            GLQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 2612        1259.0            Unf           0.0        172.0         1431.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 2612    GasA         Ex           Y      SBrkr        1444           0
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 2612                0         1444             1.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 2612          0              3              1           Gd              6
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 2612        Typ           0           NA      Attchd         2002.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 2612           RFn          2.0        577.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 2612           Y           144             40               0           0
#
#       Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 2612             0          0      NA    NA           NA         0        4
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 2612     2009       WD          Normal        NaN

# %%
# Assume year built = year remodeled
index = df[df['Year Built'] > df['Year Remod/Add']].index
df.loc[index, 'Year Built'] = df.loc[index, 'Year Remod/Add']

# %%
df[df['Full Bath'] < df['Bsmt Full Bath']][['Full Bath', 'Bsmt Full Bath']]
# Out:
#       Full Bath  Bsmt Full Bath
# 247           0             2.0
# 321           1             2.0
# 434           1             2.0
# 620           0             2.0
# 842           0             2.0
# 846           0             2.0
# 999           0             2.0
# 1349          1             2.0
# 1374          0             2.0
# 1465          0             2.0
# 1567          0             2.0
# 1687          0             1.0
# 2379          0             1.0
# 2385          0             1.0
# 2473          1             2.0

# %%
# Assume full bath and Bsmt full bath have been swapped
ind_full_bath = df[df['Full Bath'] < df['Bsmt Full Bath']].index
full_bath_aux = df.loc[ind_full_bath, 'Full Bath'].copy()
df.loc[ind_full_bath, 'Full Bath'] = df.loc[ind_full_bath, 'Bsmt Full Bath']
df.loc[ind_full_bath, 'Bsmt Full Bath'] = full_bath_aux
df[df['Full Bath'] < df['Bsmt Full Bath']]
# Out:
# Empty DataFrame
# Columns: [Order, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, Sale Condition, SalePrice]
# Index: []

# %%
df[df['Half Bath'] < df['Bsmt Half Bath']][['Half Bath', 'Bsmt Half Bath']]
# Out:
#       Half Bath  Bsmt Half Bath
# 31            0             1.0
# 39            0             1.0
# 112           0             1.0
# 160           0             1.0
# 161           0             1.0
# 183           0             1.0
# 196           0             1.0
# 198           0             1.0
# 218           0             1.0
# 273           0             1.0
# 274           0             1.0
# 296           0             1.0
# 297           0             1.0
# 378           0             1.0
# 387           0             1.0
# 481           0             1.0
# 502           0             1.0
# 519           0             1.0
# 535           0             1.0
# 554           0             1.0
# 558           0             1.0
# 582           0             1.0
# 593           0             1.0
# 607           0             1.0
# 610           0             1.0
# 630           0             1.0
# 636           0             1.0
# 641           0             1.0
# 702           0             1.0
# 712           0             1.0
# 714           0             1.0
# 721           0             1.0
# 747           0             1.0
# 751           0             1.0
# 764           0             1.0
# 769           0             1.0
# 771           0             1.0
# 817           0             1.0
# 861           0             1.0
# 864           0             1.0
# 903           0             1.0
# ...         ...             ...
# 2113          0             1.0
# 2128          0             1.0
# 2134          0             1.0
# 2139          0             1.0
# 2145          0             1.0
# 2167          0             1.0
# 2246          0             1.0
# 2251          0             1.0
# 2274          0             2.0
# 2283          0             1.0
# 2295          0             1.0
# 2341          0             1.0
# 2343          0             1.0
# 2349          0             1.0
# 2385          0             1.0
# 2392          0             1.0
# 2417          0             1.0
# 2452          0             1.0
# 2471          0             1.0
# 2480          0             1.0
# 2492          0             1.0
# 2513          0             1.0
# 2524          0             1.0
# 2567          0             1.0
# 2609          0             1.0
# 2615          0             1.0
# 2631          0             1.0
# 2650          0             1.0
# 2680          0             1.0
# 2685          0             1.0
# 2735          0             1.0
# 2743          0             1.0
# 2747          0             1.0
# 2766          0             1.0
# 2825          0             1.0
# 2841          0             1.0
# 2846          0             1.0
# 2854          0             1.0
# 2874          0             1.0
# 2896          0             1.0
# 2925          0             1.0
#
# [134 rows x 2 columns]

# %%
# Assume half bath and Bsmt half bath have been swapped
ind_half_bath = df[df['Half Bath'] < df['Bsmt Half Bath']].index
half_bath_aux = df.loc[ind_half_bath, 'Half Bath'].copy()
df.loc[ind_half_bath, 'Half Bath'] = df.loc[ind_half_bath, 'Bsmt Half Bath']
df.loc[ind_half_bath, 'Bsmt Full Bath'] = half_bath_aux
df[df['Half Bath'] < df['Bsmt Half Bath']]
# Out:
# Empty DataFrame
# Columns: [Order, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, Sale Condition, SalePrice]
# Index: []

# %%
df[df['Year Built'] > df['Garage Yr Blt']][['Year Built', 'Garage Yr Blt', 'Year Remod/Add']]
# Out:
#       Year Built  Garage Yr Blt  Year Remod/Add
# 140         1963         1962.0            1963
# 154         1935         1926.0            1950
# 330         1978         1960.0            1978
# 414         1927         1920.0            1950
# 476         1950         1949.0            1950
# 1029        1959         1954.0            1959
# 1281        1935         1920.0            1998
# 1316        1959         1956.0            1959
# 1464        2006         2005.0            2007
# 1474        2006         2005.0            2006
# 1527        1910         1900.0            1998
# 1537        1923         1922.0            2000
# 1662        1930         1925.0            1950
# 1899        2005         2003.0            2005
# 2063        1941         1940.0            1950
# 2118        1967         1961.0            2007
# 2655        2010         2009.0            2010
# 2861        1945         1925.0            1995

# %%
# Assume Year Built and Garage Yr Blt have been swaped
ind_year_built = df[df['Year Built'] > df['Garage Yr Blt']].index
year_built_aux = df.loc[ind_year_built, 'Year Built'].copy()
df.loc[ind_year_built, 'Year Built'] = df.loc[ind_year_built, 'Garage Yr Blt']
df.loc[ind_year_built, 'Garage Yr Blt'] = year_built_aux
df[df['Year Built'] > df['Garage Yr Blt']][['Year Built', 'Garage Yr Blt', 'Year Remod/Add']]
# Out:
# Empty DataFrame
# Columns: [Year Built, Garage Yr Blt, Year Remod/Add]
# Index: []

# %%
# Arbitrary set NaN Garage Yr Blt (corresponding to No garage) to one year before first garage year built
df.loc[df['Garage Yr Blt'].isna(), 'Garage Yr Blt'] = df['Garage Yr Blt'].min()-1

# %%
# Check consistency of number of rooms
df[df['TotRms AbvGrd'] < (df['Bedroom AbvGr']+ df['Kitchen AbvGr'])]
# Out:
# Empty DataFrame
# Columns: [Order, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, Sale Condition, SalePrice]
# Index: []

# %%
# Check consistency of garage data
df[
    (df['Garage Type'] == 'NA') & 
    ((df['Garage Finish'] != 'NA') | (df['Garage Cars'] != 0) |
     (df['Garage Area'] != 0) | (df['Garage Qual'] != 'NA') | (df['Garage Cond'] != 'NA'))]
# Out:
# Empty DataFrame
# Columns: [Order, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin SF 1, BsmtFin Type 2, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Pool QC, Fence, Misc Feature, Misc Val, Mo Sold, Yr Sold, Sale Type, Sale Condition, SalePrice]
# Index: []

# %%
df[discrete_cols].dtypes
# Out:
# Order               int64
# Year Built        float64
# Year Remod/Add      int64
# Bsmt Full Bath    float64
# Bsmt Half Bath    float64
# Full Bath         float64
# Half Bath         float64
# Bedroom AbvGr       int64
# Kitchen AbvGr       int64
# TotRms AbvGrd       int64
# Fireplaces          int64
# Garage Yr Blt     float64
# Garage Cars       float64
# Mo Sold             int64
# Yr Sold             int64
# dtype: object

# %%
df[discrete_cols] = df[discrete_cols].astype(int)

# %%
df[discrete_cols].dtypes
# Out:
# Order             int64
# Year Built        int64
# Year Remod/Add    int64
# Bsmt Full Bath    int64
# Bsmt Half Bath    int64
# Full Bath         int64
# Half Bath         int64
# Bedroom AbvGr     int64
# Kitchen AbvGr     int64
# TotRms AbvGrd     int64
# Fireplaces        int64
# Garage Yr Blt     int64
# Garage Cars       int64
# Mo Sold           int64
# Yr Sold           int64
# dtype: object

# %% [markdown]
# # Fix continuous columns

# %%
continuous_ser_na = df[continuous_cols].isna().sum()
continuous_ser_na[continuous_ser_na > 0]
# Out:
# Lot Frontage     490
# Mas Vnr Area      23
# BsmtFin SF 1       1
# BsmtFin SF 2       1
# Bsmt Unf SF        1
# Total Bsmt SF      1
# SalePrice        500
# dtype: int64

# %%
df[df['Total Bsmt SF'].isna()]
# Out:
#      Order        PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 104   1342  903230120          20        RM          99.0      5940   Pave
#
#     Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 104    NA       IR1          Lvl    AllPub        FR3        Gtl      BrkSide
#
#     Condition 1 Condition 2 Bldg Type House Style Overall Qual Overall Cond  \
# 104       Feedr        Norm      1Fam      1Story            4            7
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 104        1946            1950      Gable   CompShg      MetalSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 104       CBlock         None           0.0         TA         TA      PConc
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 104        NA        NA            NA             NA           NaN
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# 104             NA           NaN          NaN            NaN    GasA
#
#     Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 104         TA           Y      FuseA         896           0
#
#      Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 104                0          896               1               0          1
#
#      Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 104          0              2              1           TA              4
#
#     Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 104        Typ           0           NA      Detchd           1946
#
#     Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 104           Unf            1        280.0          TA          TA
#
#     Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 104           Y             0              0               0           0
#
#      Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 104             0          0      NA  MnPrv           NA         0        4
#
#      Yr Sold Sale Type Sale Condition  SalePrice
# 104     2008     ConLD        Abnorml    79000.0

# %%
# Remove the entry because there are too many incoherencies (e.g. No basement but bath in the basement)
df.drop(index=df[df['Total Bsmt SF'].isna()].index, inplace=True)

# %%
df[df['Mas Vnr Area'].isna()][['Mas Vnr Type', 'Mas Vnr Area']]
# Out:
#      Mas Vnr Type  Mas Vnr Area
# 66        Missing           NaN
# 83        Missing           NaN
# 101       Missing           NaN
# 159       Missing           NaN
# 201       Missing           NaN
# 270       Missing           NaN
# 352       Missing           NaN
# 447       Missing           NaN
# 456       Missing           NaN
# 457       Missing           NaN
# 465       Missing           NaN
# 624       Missing           NaN
# 851       Missing           NaN
# 891       Missing           NaN
# 1098      Missing           NaN
# 1480      Missing           NaN
# 1592      Missing           NaN
# 1832      Missing           NaN
# 2137      Missing           NaN
# 2219      Missing           NaN
# 2604      Missing           NaN
# 2659      Missing           NaN
# 2832      Missing           NaN

# %%
# Seems fair to assume that Missing Mas Vnr Type corresponds to None
index = df[df['Mas Vnr Type'] == 'Missing'].index
df.loc[index, 'Mas Vnr Type'] = 'None'
df.loc[index, 'Mas Vnr Area'] = 0.

# %%
df[df['Lot Frontage'].isna()]
# Out:
#       Order         PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       484   528275070          60        RL           NaN      8795   Pave
# 13      785   905377130          30        RL           NaN     12342   Pave
# 26      583   534128010          60        RL           NaN     10382   Pave
# 34     1611  1007100110          70   I (all)           NaN     56600   Pave
# 35     2893   916252170         120        RM           NaN      8239   Pave
# 38     1755   528275110          60        RL           NaN      8740   Pave
# 57     2789   907230240         160        RH           NaN      3612   Pave
# 70     2511   533221080         160        FV           NaN      2998   Pave
# 78     1264   535426260          20        RL           NaN     10920   Pave
# 80      479   528240060          80        RL           NaN      7750   Pave
# 81     2353   527358090          85        RL           NaN      9927   Pave
# 89     1573   916325080          20        RL           NaN     15498   Pave
# 91     1358   903427090          70        RM           NaN      5100   Pave
# 96      564   532478020          20        RL           NaN     15676   Pave
# 100    2301   923275010          20        RL           NaN     11000   Pave
# 101    2230   909475070          20        RL           NaN     32668   Pave
# 112     598   534251030          85        RL           NaN     16500   Pave
# 113     315   916125360          20        RL           NaN     57200   Pave
# 124     954   914476380          80        RL           NaN      9947   Pave
# 127    2717   905107300          80        RL           NaN      7176   Pave
# 137     937   909452050          80        RL           NaN     13607   Pave
# 141    2360   527402210          20        RL           NaN     15870   Pave
# 145     230   905109170          20        RL           NaN     20062   Pave
# 151     565   533135020          60        RL           NaN     11949   Pave
# 157     964   916403200          60        RL           NaN      9839   Pave
# 158      58   528250100          80        RL           NaN      7750   Pave
# 170    1158   533125080          60        RL           NaN      9205   Pave
# 176     795   905475500          20        RL           NaN     11500   Pave
# 196    1652   527328020          80        RL           NaN     10395   Pave
# 205     582   534127170          20        RL           NaN      9156   Pave
# 214     145   535154050          20        RL           NaN     12160   Pave
# 220    2793   907255010          20        RL           NaN     11088   Pave
# 221    1102   528326110          60        RL           NaN     11000   Pave
# 229    2287   923228200         180        RM           NaN      1533   Pave
# 232    1363   903455030          50        RM           NaN     10320   Pave
# 240     358   527163070          60        RL           NaN      9765   Pave
# 247     233   905325030          40        RL           NaN     23595   Pave
# 248     611   534403370          80        RL           NaN     12095   Pave
# 250    2075   905376090          20        RL           NaN     17541   Pave
# 254    1388   905200160          20        RL           NaN      9000   Pave
# 264    1852   533242090          60        FV           NaN      8010   Pave
# ...     ...         ...         ...       ...           ...       ...    ...
# 2658    492   528292040          60        RL           NaN     24682   Pave
# 2662     24   527402200          20        RL           NaN     11241   Pave
# 2663    984   923275140          20        RL           NaN      8780   Pave
# 2671   2725   905201090          20        RL           NaN     14175   Pave
# 2690    193   903206120          75        RL           NaN      7793   Pave
# 2699   2736   905426150          80        RL           NaN     19690   Pave
# 2703   2014   903231090          50        RM           NaN      6240   Pave
# 2704   2860   909276010          70        RL           NaN     11435   Pave
# 2708   1773   528366050          20        RL           NaN     12692   Pave
# 2717   2791   907252050          60        RL           NaN      9930   Pave
# 2728   1082   528228405         120        RM           NaN      3940   Pave
# 2729   2425   528228430         120        RM           NaN      3072   Pave
# 2730   1200   534250370          60        RL           NaN      8963   Pave
# 2742    559   532376070          20        RL           NaN      9316   Pave
# 2746   2403   528172150          60        RL           NaN     13215   Pave
# 2747   2120   907125040          20        RL           NaN     14217   Pave
# 2752   1265   535426350          20        RL           NaN     12929   Pave
# 2764   1050   527455270          20        RL           NaN      9477   Pave
# 2769   1449   907202190          20        RL           NaN      9216   Pave
# 2776    616   534451110          50        RL           NaN      7015   Pave
# 2791   1628   527165020          80        RL           NaN     10784   Pave
# 2796   2484   531478010          20        RH           NaN      8900   Pave
# 2797    818   906230030          90        RL           NaN      7976   Pave
# 2818    290   909176150          30        RL           NaN      7890   Pave
# 2824   1831   532479120          85        RL           NaN     16647   Pave
# 2834   1812   531384070          60        RL           NaN     11613   Pave
# 2837   1670   527404150          20        RL           NaN      7340   Pave
# 2853   1016   527276040          20        RL           NaN     47280   Pave
# 2859    938   909475040          20        RL           NaN     17597   Pave
# 2861   1344   903232030          30        RM           NaN      6120   Pave
# 2865    243   905475510          20        RL           NaN     11200   Pave
# 2869   1531   909275040          70        RL           NaN      9650   Pave
# 2874    114   534152070          50        RL           NaN     18837   Pave
# 2875   1495   908151040          80        RL           NaN      9638   Pave
# 2892     15   527182190         120        RL           NaN      6820   Pave
# 2895   2671   903200050          30        RL           NaN      7446   Pave
# 2897    784   905377010          20        RL           NaN     17140   Pave
# 2901    327   923225300         160        RM           NaN      1974   Pave
# 2908    879   907290210         120        RM           NaN      4435   Pave
# 2912    721   902331010          30   C (all)           NaN      3300   Pave
# 2926   2518   533252020          20        RL           NaN     11250   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0       NA       IR1          Lvl    AllPub     Inside        Gtl
# 13      NA       IR1          Lvl    AllPub     Inside        Gtl
# 26      NA       IR1          Lvl    AllPub     Corner        Gtl
# 34      NA       IR1          Low    AllPub     Inside        Gtl
# 35      NA       IR1          Lvl    AllPub     Inside        Gtl
# 38      NA       IR1          Lvl    AllPub     Inside        Gtl
# 57      NA       IR1          Lvl    AllPub     Inside        Gtl
# 70      NA       Reg          Lvl    AllPub     Inside        Gtl
# 78      NA       IR1          Lvl    AllPub     Corner        Gtl
# 80      NA       Reg          Lvl    AllPub     Inside        Gtl
# 81      NA       IR1          Lvl    AllPub     Inside        Gtl
# 89      NA       IR1          Lvl    AllPub     Corner        Gtl
# 91    Grvl       Reg          Lvl    AllPub     Inside        Gtl
# 96      NA       IR1          Low    AllPub     Inside        Gtl
# 100     NA       IR2          Lvl    AllPub     Corner        Gtl
# 101     NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 112     NA       Reg          Lvl    AllPub     Inside        Gtl
# 113     NA       IR1          Bnk    AllPub     Inside        Sev
# 124     NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 127     NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 137     NA       IR1          Lvl    AllPub     Inside        Gtl
# 141     NA       IR1          Lvl    AllPub     Corner        Gtl
# 145     NA       IR1          Low    AllPub     Inside        Mod
# 151     NA       Reg          Lvl    AllPub     Inside        Gtl
# 157     NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 158     NA       IR1          Lvl    AllPub     Inside        Gtl
# 170     NA       IR1          Lvl    AllPub     Inside        Gtl
# 176     NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 196     NA       IR1          Lvl    AllPub        FR2        Gtl
# 205     NA       IR1          Lvl    AllPub     Inside        Gtl
# 214     NA       IR1          Lvl    AllPub     Inside        Gtl
# 220     NA       Reg          Lvl    AllPub     Corner        Gtl
# 221     NA       Reg          Lvl    AllPub        FR2        Gtl
# 229     NA       Reg          Lvl    AllPub     Inside        Gtl
# 232   Grvl       Reg          Lvl    AllPub     Inside        Gtl
# 240     NA       IR2          Lvl    AllPub     Corner        Gtl
# 247     NA       Reg          Low    AllPub     Inside        Sev
# 248     NA       IR1          Lvl    AllPub     Corner        Gtl
# 250     NA       IR1          Lvl    AllPub     Corner        Gtl
# 254     NA       Reg          Lvl    AllPub     Inside        Gtl
# 264   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2658    NA       IR3          Lvl    AllPub    CulDSac        Gtl
# 2662    NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 2663    NA       IR1          Lvl    AllPub     Corner        Gtl
# 2671    NA       Reg          Bnk    AllPub     Corner        Mod
# 2690    NA       IR1          Bnk    AllPub     Corner        Gtl
# 2699    NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 2703    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2704    NA       IR1          HLS    AllPub     Corner        Mod
# 2708    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2717    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2728    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2729    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2730    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2742    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2746    NA       IR1          Lvl    AllPub     Corner        Gtl
# 2747    NA       IR2          Lvl    AllPub    CulDSac        Gtl
# 2752    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2764    NA       Reg          Lvl    AllPub     Corner        Gtl
# 2769    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2776    NA       IR1          Bnk    AllPub     Corner        Gtl
# 2791    NA       IR1          Lvl    AllPub        FR2        Gtl
# 2796    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2797    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2818    NA       Reg          Lvl    AllPub     Corner        Gtl
# 2824    NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 2834    NA       IR2          Lvl    AllPub     Corner        Gtl
# 2837    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2853    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2859    NA       Reg          Bnk    AllPub     Inside        Gtl
# 2861    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2865    NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 2869    NA       IR1          HLS    AllPub     Corner        Gtl
# 2874    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2875    NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 2892    NA       IR1          Lvl    AllPub     Corner        Gtl
# 2895    NA       Reg          Lvl    AllPub     Corner        Gtl
# 2897    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2901    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2908    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2912    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2926    NA       IR1          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style Overall Qual  \
# 0         Gilbert        Norm        Norm      1Fam      2Story            7
# 13        Edwards        Norm        Norm      1Fam      1Story            4
# 26         NWAmes        PosN        Norm      1Fam      2Story            7
# 34         IDOTRR        Norm        Norm      1Fam      2.5Unf            5
# 35        GrnHill        Norm        Norm    TwnhsE      1Story            7
# 38        Gilbert        Norm        Norm      1Fam      2Story            7
# 57        Landmrk        Norm        Norm     Twnhs      2Story            6
# 70        Somerst        Norm        Norm    TwnhsE      2Story            6
# 78          NAmes        Norm        Norm      1Fam      1Story            6
# 80        Gilbert        Norm        Norm      1Fam        SLvl            8
# 81         NWAmes        Norm        Norm      1Fam      SFoyer            7
# 89         Timber        Norm        Norm      1Fam      1Story            8
# 91        OldTown        Norm        Norm      1Fam      2Story            8
# 96        Veenker        Norm        Norm      1Fam      1Story            8
# 100       Mitchel        Norm        Norm      1Fam      1Story            5
# 101       Crawfor        Norm        Norm      1Fam      1Story            6
# 112        NWAmes        Norm        Norm      1Fam      SFoyer            6
# 113        Timber        Norm        Norm      1Fam      1Story            5
# 124       Mitchel        Norm        Norm      1Fam        SLvl            7
# 127        Sawyer        Norm        Norm      1Fam        SLvl            6
# 137       Crawfor        Norm        Norm      1Fam        SLvl            6
# 141         NAmes        Norm        Norm      1Fam      1Story            5
# 145       ClearCr        Norm        Norm      1Fam      1Story            7
# 151       NoRidge        Norm        Norm      1Fam      2Story            7
# 157        Timber        Norm        Norm      1Fam      2Story            6
# 158       Gilbert        Norm        Norm      1Fam        SLvl            7
# 170       NoRidge        Norm        Norm      1Fam      2Story            6
# 176       Edwards        Norm        Norm      1Fam      1Story            4
# 196        NWAmes        Norm        Norm      1Fam        SLvl            6
# 205        NWAmes        PosN        Norm      1Fam      1Story            6
# 214         NAmes        Norm        Norm      1Fam      1Story            5
# 220       CollgCr        Norm        Norm      1Fam      1Story            8
# 221       NoRidge        Norm        Norm      1Fam      2Story            9
# 229       MeadowV        Norm        Norm     Twnhs        SLvl            4
# 232        IDOTRR        Norm        Norm      1Fam      1.5Fin            5
# 240       Gilbert        Norm        Norm      1Fam      2Story            6
# 247       ClearCr        Norm        Norm      1Fam      1Story            7
# 248         NAmes        Norm        Norm      1Fam        SLvl            6
# 250       Edwards        Norm        Norm      1Fam      1Story            5
# 254        Sawyer        Norm        Norm      1Fam      1Story            5
# 264       Somerst        Norm        Norm      1Fam      2Story            8
# ...           ...         ...         ...       ...         ...          ...
# 2658      Gilbert        RRAn        Norm      1Fam      2Story            6
# 2662        NAmes        Norm        Norm      1Fam      1Story            6
# 2663      Mitchel        Norm        Norm      1Fam      1Story            5
# 2671       Sawyer        Norm        Norm      1Fam      1Story            5
# 2690      BrkSide        Norm        Norm      1Fam      2.5Unf            7
# 2699      Edwards        Norm        Norm      1Fam        SLvl            6
# 2703      BrkSide        Norm        Norm      1Fam      1.5Fin            6
# 2704      Crawfor        Norm        Norm      1Fam      2Story            8
# 2708      NoRidge        Norm        Norm      1Fam      1Story            8
# 2717      CollgCr        Norm        Norm      1Fam      2Story            7
# 2728      Blmngtn        Norm        Norm    TwnhsE      1Story            7
# 2729      Blmngtn        Norm        Norm    TwnhsE      1Story            7
# 2730       NWAmes        Norm        Norm      1Fam      2Story            8
# 2742       Sawyer        Norm        Norm      1Fam      1Story            5
# 2746      NridgHt        Norm        Norm      1Fam      2Story            8
# 2747      CollgCr        Norm        Norm      1Fam      1Story            5
# 2752        NAmes        Norm        Norm      1Fam      1Story            6
# 2764        NAmes        Norm        Norm      1Fam      1Story            5
# 2769      CollgCr        Norm        Norm      1Fam      1Story            5
# 2776      BrkSide        Norm        Norm      1Fam      1.5Fin            5
# 2791      Gilbert        Norm        Norm      1Fam        SLvl            7
# 2796      SawyerW        Norm        Norm      1Fam      1Story            4
# 2797      SawyerW       Feedr        Norm    Duplex      2Story            7
# 2818        SWISU        Norm        Norm      1Fam      1Story            6
# 2824       Sawyer        RRAe        Norm      1Fam      SFoyer            5
# 2834      SawyerW        Norm        Norm      1Fam      2Story            6
# 2837        NAmes        Norm        Norm      1Fam      1Story            4
# 2853      Gilbert        Norm        Norm      1Fam      1Story            6
# 2859      Crawfor        Norm        Norm      1Fam      1Story            7
# 2861      BrkSide        Norm        Norm      1Fam      1Story            5
# 2865      Edwards        Norm        Norm      1Fam      1Story            5
# 2869      Crawfor        Norm        Norm      1Fam      2Story            6
# 2874       NWAmes        Norm        Norm      1Fam      1.5Fin            6
# 2875      Edwards        Norm        Norm      1Fam        SLvl            6
# 2892      StoneBr        Norm        Norm    TwnhsE      1Story            8
# 2895      BrkSide       Feedr        Norm      1Fam      1Story            4
# 2897      Edwards        Norm        Norm      1Fam      1Story            4
# 2901      MeadowV        Norm        Norm    TwnhsE      2Story            4
# 2908      CollgCr        Norm        Norm    TwnhsE      1Story            6
# 2912      OldTown        Norm        Norm      1Fam      1Story            4
# 2926      Veenker        Norm        Norm      1Fam      1Story            6
#
#      Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 0               5        2000            2000      Gable   CompShg
# 13              5        1940            1950      Gable   CompShg
# 26              6        1973            1973      Gable   CompShg
# 34              1        1900            1950        Hip   CompShg
# 35              5        1986            1986      Gable   CompShg
# 38              5        2002            2002      Gable   CompShg
# 57              5        1993            1994      Gable   CompShg
# 70              5        2000            2000      Gable   CompShg
# 78              5        1960            1960        Hip   CompShg
# 80              5        2002            2002        Hip   CompShg
# 81              5        1976            1976      Gable   CompShg
# 89              6        1976            1976        Hip   WdShake
# 91              7        1925            1996        Hip   CompShg
# 96              8        1980            1980      Gable   CompShg
# 100             6        1976            2003      Gable   CompShg
# 101             3        1957            1975        Hip   CompShg
# 112             5        1971            1971        Hip   CompShg
# 113             5        1948            1950      Gable   CompShg
# 124             5        1990            1991      Gable   CompShg
# 127             6        1978            1978      Gable   CompShg
# 137             6        1986            1986      Gable   CompShg
# 141             5        1969            1969      Gable   CompShg
# 145             7        1977            2001        Hip   CompShg
# 151             8        1991            2008      Gable   CompShg
# 157             8        1980            2006      Gable   CompShg
# 158             5        2000            2000      Gable   CompShg
# 170             5        1990            1991        Hip   CompShg
# 176             3        1957            1957      Gable   CompShg
# 196             6        1978            1978      Gable   CompShg
# 205             7        1968            1968        Hip   CompShg
# 214             5        1959            1959        Hip   CompShg
# 220             5        2002            2002        Hip   CompShg
# 221             5        2000            2000        Hip   CompShg
# 229             5        1970            1970      Gable   CompShg
# 232             6        1915            1978      Gable   CompShg
# 240             8        1993            1993      Gable   CompShg
# 247             6        1979            1979       Shed   WdShake
# 248             6        1964            1964      Gable   CompShg
# 250             7        1948            2005        Hip   CompShg
# 254             3        1959            1959      Gable   CompShg
# 264             5        2003            2004        Hip   CompShg
# ...           ...         ...             ...        ...       ...
# 2658            5        1999            1999      Gable   CompShg
# 2662            7        1970            1970      Gable   CompShg
# 2663            5        1985            1985      Gable   CompShg
# 2671            6        1956            1987      Gable   CompShg
# 2690            7        1922            2005      Gable   CompShg
# 2699            7        1966            1966       Flat   Tar&Grv
# 2703            5        1938            1950      Gable   CompShg
# 2704            7        1929            1950      Gable   CompShg
# 2708            5        1992            1993        Hip   CompShg
# 2717            5        2002            2002      Gable   CompShg
# 2728            5        2004            2004        Hip   CompShg
# 2729            5        2004            2004        Hip   CompShg
# 2730            9        1976            1996        Hip   CompShg
# 2742            5        1965            1965      Gable   CompShg
# 2746            5        2004            2004      Gable   CompShg
# 2747            5        1994            1994      Gable   CompShg
# 2752            6        1960            1993      Gable   CompShg
# 2764            5        1966            1966      Gable   CompShg
# 2769            6        1975            1975      Gable   CompShg
# 2776            4        1950            1950      Gable   CompShg
# 2791            5        1991            1992      Gable   CompShg
# 2796            4        1966            1966      Gable   CompShg
# 2797            5        2000            2000        Hip   CompShg
# 2818            6        1939            1950      Gable   CompShg
# 2824            5        1975            1981      Gable   CompShg
# 2834            5        1993            1997      Gable   CompShg
# 2837            6        1971            1971      Gable   CompShg
# 2853            5        1950            1950        Hip   CompShg
# 2859            9        1971            2009        Hip   CompShg
# 2861            6        1925            1995      Gable   CompShg
# 2865            3        1964            1964      Gable   CompShg
# 2869            3        1923            1950        Hip   CompShg
# 2874            5        1978            1978      Gable   CompShg
# 2875            6        1977            1977        Hip   CompShg
# 2892            5        1985            1985      Gable   CompShg
# 2895            5        1941            1950      Gable   CompShg
# 2897            6        1956            1956      Gable   CompShg
# 2901            5        1973            1973      Gable   CompShg
# 2908            5        2003            2003      Gable   CompShg
# 2912            3        1910            1950      Gable   CompShg
# 2926            6        1977            1977      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 0         VinylSd      VinylSd         None           0.0         Gd
# 13        VinylSd      VinylSd         None           0.0         TA
# 26        HdBoard      HdBoard        Stone         240.0         TA
# 34        Wd Sdng      Wd Sdng         None           0.0         TA
# 35        BrkFace      Wd Sdng         None           0.0         Gd
# 38        VinylSd      VinylSd         None           0.0         Gd
# 57        VinylSd      VinylSd         None           0.0         TA
# 70        MetalSd      MetalSd      BrkFace         513.0         Gd
# 78        MetalSd      MetalSd      BrkFace         212.0         TA
# 80        VinylSd      VinylSd         None           0.0         Gd
# 81        VinylSd      Wd Shng        Stone         252.0         Gd
# 89          Stone      HdBoard         None           0.0         Gd
# 91         Stucco      Wd Shng         None           0.0         TA
# 96        VinylSd      VinylSd      BrkFace         115.0         Gd
# 100       Plywood      Plywood         None           0.0         TA
# 101       Wd Sdng        Stone         None           0.0         Gd
# 112       HdBoard      HdBoard      BrkFace         509.0         TA
# 113       Wd Sdng      Wd Sdng         None           0.0         TA
# 124       HdBoard      HdBoard         None           0.0         TA
# 127       HdBoard      HdBoard      BrkFace         200.0         TA
# 137       VinylSd      VinylSd      BrkFace         242.0         TA
# 141       VinylSd      Plywood         None           0.0         TA
# 145       Wd Sdng      Wd Sdng         None           0.0         Gd
# 151       VinylSd      VinylSd      BrkFace         196.0         Gd
# 157       MetalSd      MetalSd         None           0.0         TA
# 158       VinylSd      VinylSd         None           0.0         TA
# 170       HdBoard      HdBoard      BrkFace         304.0         Gd
# 176       Wd Sdng      Wd Sdng         None           0.0         TA
# 196       HdBoard      HdBoard      BrkFace         233.0         TA
# 205       BrkFace      BrkFace         None           0.0         TA
# 214       Plywood      Plywood      BrkFace         180.0         TA
# 220        Stucco       Stucco         None           0.0         Gd
# 221       VinylSd      VinylSd      BrkFace         295.0         Gd
# 229       CemntBd      CmentBd         None           0.0         TA
# 232       HdBoard      HdBoard         None           0.0         TA
# 240       VinylSd      VinylSd      BrkFace          68.0         Ex
# 247       Plywood      Plywood         None           0.0         Gd
# 248       MetalSd      HdBoard      BrkFace         115.0         TA
# 250       Wd Sdng      Wd Sdng         None           0.0         TA
# 254       Wd Sdng      Plywood         None           0.0         TA
# 264       CemntBd      CmentBd         None           0.0         Gd
# ...           ...          ...          ...           ...        ...
# 2658      VinylSd      VinylSd         None           0.0         TA
# 2662      Wd Sdng      Wd Sdng      BrkFace         180.0         TA
# 2663      HdBoard      Plywood         None           0.0         TA
# 2671      CemntBd      Wd Sdng         None           0.0         TA
# 2690      Wd Sdng      Wd Sdng         None           0.0         TA
# 2699      Plywood      Plywood         None           0.0         Gd
# 2703      VinylSd      VinylSd         None           0.0         TA
# 2704      BrkFace       Stucco         None           0.0         TA
# 2708      BrkFace      BrkFace         None           0.0         Gd
# 2717      VinylSd      VinylSd      BrkFace         199.0         Gd
# 2728      VinylSd      VinylSd      BrkFace          24.0         Gd
# 2729      VinylSd      VinylSd      BrkFace          18.0         Gd
# 2730      VinylSd      VinylSd      BrkFace         289.0         Ex
# 2742      HdBoard      Plywood         None           0.0         TA
# 2746      VinylSd      VinylSd      BrkFace         112.0         Gd
# 2747      VinylSd      VinylSd         None           0.0         TA
# 2752      Wd Sdng      Wd Sdng      BrkFace         276.0         TA
# 2764      HdBoard      HdBoard      BrkFace          65.0         TA
# 2769      HdBoard      HdBoard      BrkFace         176.0         TA
# 2776      MetalSd      MetalSd       BrkCmn         161.0         TA
# 2791      HdBoard      HdBoard      BrkFace          76.0         Gd
# 2796      HdBoard      HdBoard         None           0.0         TA
# 2797      VinylSd      VinylSd      BrkFace          23.0         TA
# 2818      Wd Sdng      Wd Sdng         None           0.0         TA
# 2824      HdBoard      HdBoard         None           0.0         TA
# 2834      VinylSd      VinylSd         None           0.0         Gd
# 2837      HdBoard      HdBoard         None           0.0         TA
# 2853      AsbShng      AsbShng      BrkFace          44.0         TA
# 2859      BrkFace      BrkFace         None           0.0         Gd
# 2861      Plywood      Plywood         None           0.0         TA
# 2865      Wd Sdng      Wd Sdng         None           0.0         TA
# 2869      Wd Sdng      Plywood         None           0.0         TA
# 2874      MetalSd      MetalSd         None           0.0         TA
# 2875      Plywood      Plywood         None           0.0         TA
# 2892      HdBoard      HdBoard         None           0.0         Gd
# 2895      WdShing      Wd Shng         None           0.0         TA
# 2897      VinylSd      VinylSd         None           0.0         TA
# 2901      CemntBd      CmentBd         None           0.0         TA
# 2908      VinylSd      VinylSd      BrkFace         170.0         Gd
# 2912       Stucco       Stucco         None           0.0         TA
# 2926      Plywood      Plywood         None           0.0         Gd
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA      PConc        Gd        TA            No            GLQ
# 13           TA     CBlock        TA        TA            No            BLQ
# 26           TA     CBlock        Gd        TA            Mn            ALQ
# 34           TA     BrkTil        TA        TA            No            Unf
# 35           TA     CBlock        NA        NA            NA             NA
# 38           TA      PConc        Gd        TA            No            GLQ
# 57           TA      PConc        Gd        TA            No            GLQ
# 70           TA      PConc        Gd        TA            No            GLQ
# 78           TA     CBlock        TA        TA            No            BLQ
# 80           TA      PConc        Gd        TA            No            GLQ
# 81           TA     CBlock        Ex        TA            Gd            GLQ
# 89           TA     CBlock        Gd        TA            Av            ALQ
# 91           Gd      PConc        TA        TA            No            Unf
# 96           Gd     CBlock        Gd        Gd            Gd            ALQ
# 100          TA      PConc        Gd        TA            No            LwQ
# 101          TA      PConc        TA        TA            No            Rec
# 112          TA     CBlock        Gd        TA            Av            GLQ
# 113          TA     CBlock        TA        TA            Av            BLQ
# 124          TA      PConc        Gd        TA            Av            GLQ
# 127          TA     CBlock        TA        Gd            Gd            GLQ
# 137          Gd     CBlock        TA        TA            No            ALQ
# 141          TA     CBlock        TA        TA            Mn            BLQ
# 145          Gd     CBlock        Gd        TA            Gd            ALQ
# 151          Gd      PConc        Gd        TA            No            GLQ
# 157          Gd      PConc        Gd        TA            No            ALQ
# 158          TA      PConc        Gd        TA            No            GLQ
# 170          TA      PConc        Gd        TA            No            ALQ
# 176          Gd       Slab        NA        NA            NA             NA
# 196          TA     CBlock        Gd        TA            Av            ALQ
# 205          TA     CBlock        TA        TA            No            Unf
# 214          TA     CBlock        TA        TA            No            Rec
# 220          TA      PConc        Gd        TA            No            GLQ
# 221          TA      PConc        Ex        TA            Mn            Unf
# 229          TA     CBlock        Gd        TA            Av            GLQ
# 232          Fa     BrkTil        TA        Fa            No            Unf
# 240          Gd      PConc        Gd        Gd            No            ALQ
# 247          TA      PConc        Gd        TA            Gd            GLQ
# 248          Gd     CBlock        TA        TA            Gd            Rec
# 250          Gd     CBlock        TA        Gd            Mn            BLQ
# 254          TA     CBlock        TA        TA            No            GLQ
# 264          TA      PConc        Ex        TA            No            GLQ
# ...         ...        ...       ...       ...           ...            ...
# 2658         TA      PConc        Gd        TA            No            Unf
# 2662         TA     CBlock        TA        TA            No            ALQ
# 2663         TA     CBlock        TA        TA            No            ALQ
# 2671         TA     CBlock        TA        TA            No            Rec
# 2690         TA     BrkTil        Gd        TA            No            BLQ
# 2699         Gd     CBlock        Gd        TA            Av            Unf
# 2703         TA     BrkTil        TA        TA            No            LwQ
# 2704         TA      PConc        Gd        TA            No            Unf
# 2708         TA      PConc        Gd        TA            No            GLQ
# 2717         TA      PConc        Gd        TA            No            GLQ
# 2728         TA      PConc        Gd        TA            No            GLQ
# 2729         TA      PConc        Gd        TA            No            GLQ
# 2730         Gd     CBlock        TA        Gd            No            GLQ
# 2742         TA     CBlock        TA        TA            No            Rec
# 2746         TA      PConc        Gd        TA            No            GLQ
# 2747         TA      PConc        Gd        TA            No            ALQ
# 2752         TA     CBlock        TA        TA            Gd            GLQ
# 2764         TA     CBlock        TA        TA            No            Rec
# 2769         TA     CBlock        TA        TA            Av            ALQ
# 2776         TA     CBlock        TA        TA            No            LwQ
# 2791         TA      PConc        Gd        TA            No            Unf
# 2796         TA     CBlock        TA        TA            No            Rec
# 2797         TA      PConc        Ex        TA            No            GLQ
# 2818         TA     CBlock        TA        TA            No            Rec
# 2824         TA     CBlock        Gd        TA            Gd            ALQ
# 2834         TA      PConc        Gd        TA            No            ALQ
# 2837         TA     CBlock        TA        TA            No            ALQ
# 2853         TA     CBlock        TA        TA            No            Unf
# 2859         Gd     CBlock        Gd        TA            No            GLQ
# 2861         Gd     CBlock        NA        NA            NA             NA
# 2865         Fa     CBlock        TA        TA            Mn            Unf
# 2869         TA     BrkTil        TA        TA            No            Unf
# 2874         TA      PConc        Gd        TA            Mn            ALQ
# 2875         TA     CBlock        TA        TA            Av            ALQ
# 2892         TA      PConc        Gd        TA            Av            GLQ
# 2895         TA     CBlock        TA        TA            No            Rec
# 2897         TA     CBlock        TA        TA            No            ALQ
# 2901         TA     CBlock        TA        TA            No            BLQ
# 2908         TA      PConc        Gd        TA            Av            GLQ
# 2912         TA     BrkTil        TA        TA            No            Unf
# 2926         TA     CBlock        Gd        TA            No            ALQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 0            300.0            Unf           0.0        652.0          952.0
# 13           262.0            Unf           0.0        599.0          861.0
# 26           859.0            BLQ          32.0        216.0         1107.0
# 34             0.0            Unf           0.0        686.0          686.0
# 35             0.0             NA           0.0          0.0            0.0
# 38           574.0            Unf           0.0        280.0          854.0
# 57           338.0            Unf           0.0        292.0          630.0
# 70           353.0            Unf           0.0        403.0          756.0
# 78           733.0            Unf           0.0        520.0         1253.0
# 80           353.0            Unf           0.0         55.0          408.0
# 81          1005.0            Unf           0.0         42.0         1047.0
# 89          1165.0            LwQ         400.0          0.0         1565.0
# 91             0.0            Unf           0.0        588.0          588.0
# 96          1733.0            Rec          92.0        189.0         2014.0
# 100         1090.0            Unf           0.0          0.0         1090.0
# 101         1219.0            Unf           0.0        816.0         2035.0
# 112          962.0            Unf           0.0        270.0         1232.0
# 113          353.0            Rec         334.0         60.0          747.0
# 124          611.0            Unf           0.0        577.0         1188.0
# 127          794.0            Unf           0.0        166.0          960.0
# 137          454.0            Unf           0.0        118.0          572.0
# 141           75.0            Rec         791.0        230.0         1096.0
# 145         1092.0            Unf           0.0        328.0         1420.0
# 151          601.0            ALQ         216.0        158.0          975.0
# 157          462.0            Unf           0.0        250.0          712.0
# 158          250.0            Unf           0.0        134.0          384.0
# 170          704.0            Unf           0.0        226.0          930.0
# 176            0.0             NA           0.0          0.0            0.0
# 196          605.0            Unf           0.0        427.0         1032.0
# 205            0.0            Unf           0.0       1489.0         1489.0
# 214         1000.0            Unf           0.0        188.0         1188.0
# 220          872.0            Unf           0.0        476.0         1348.0
# 221            0.0            Unf           0.0       1519.0         1519.0
# 229          503.0            Unf           0.0         27.0          530.0
# 232            0.0            Unf           0.0        880.0          880.0
# 240          310.0            Unf           0.0        370.0          680.0
# 247         1258.0            Unf           0.0         74.0         1332.0
# 248          564.0            Unf           0.0        563.0         1127.0
# 250          300.0            Unf           0.0        109.0          409.0
# 254          288.0            Unf           0.0        718.0         1006.0
# 264          964.0            Unf           0.0         90.0         1054.0
# ...            ...            ...           ...          ...            ...
# 2658           0.0            Unf           0.0        841.0          841.0
# 2662         578.0            Unf           0.0        426.0         1004.0
# 2663         625.0            Unf           0.0        208.0          833.0
# 2671         988.0            Unf           0.0        200.0         1188.0
# 2690         474.0            Unf           0.0        634.0         1108.0
# 2699           0.0            Unf           0.0        697.0          697.0
# 2703          52.0            Unf           0.0        809.0          861.0
# 2704           0.0            Unf           0.0        792.0          792.0
# 2708        1231.0            Unf           0.0       1969.0         3200.0
# 2717         456.0            Unf           0.0        370.0          826.0
# 2728        1087.0            Unf           0.0        306.0         1393.0
# 2729        1059.0            Unf           0.0        306.0         1365.0
# 2730         575.0            ALQ          80.0        487.0         1142.0
# 2742         544.0            Unf           0.0        480.0         1024.0
# 2746         994.0            Unf           0.0        426.0         1420.0
# 2747         550.0            Unf           0.0        472.0         1022.0
# 2752         697.0            Unf           0.0        384.0         1081.0
# 2764         340.0            Unf           0.0        524.0          864.0
# 2769         294.0            Unf           0.0        782.0         1076.0
# 2776         185.0            Unf           0.0        524.0          709.0
# 2791           0.0            Unf           0.0        384.0          384.0
# 2796        1056.0            Unf           0.0          0.0         1056.0
# 2797         820.0            Unf           0.0        348.0         1168.0
# 2818         238.0            Unf           0.0        618.0          856.0
# 2824        1390.0            Unf           0.0          0.0         1390.0
# 2834         480.0            Unf           0.0        384.0          864.0
# 2837         322.0            Unf           0.0        536.0          858.0
# 2853           0.0            Unf           0.0       1488.0         1488.0
# 2859         803.0            ALQ         419.0        581.0         1803.0
# 2861           0.0             NA           0.0          0.0            0.0
# 2865           0.0            Unf           0.0       1250.0         1250.0
# 2869           0.0            Unf           0.0        784.0          784.0
# 2874         687.0            LwQ          46.0        491.0         1224.0
# 2875         368.0            Rec         120.0        541.0         1029.0
# 2892         368.0            BLQ        1120.0          0.0         1488.0
# 2895         266.0            Unf           0.0        522.0          788.0
# 2897        1059.0            Unf           0.0         75.0         1134.0
# 2901         334.0            Unf           0.0        212.0          546.0
# 2908         685.0            Unf           0.0        163.0          848.0
# 2912           0.0            Unf           0.0        624.0          624.0
# 2926         767.0            Unf           0.0        441.0         1208.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0       GasA         Ex           Y      SBrkr         980        1276
# 13      GasA         Ex           Y      SBrkr         861           0
# 26      GasA         Ex           Y      SBrkr        1107         983
# 34      GasA         Ex           Y      SBrkr        1150         686
# 35      GasA         Gd           Y      SBrkr        1295           0
# 38      GasA         Ex           Y      SBrkr         864        1131
# 57      GasA         Ex           Y      SBrkr         630         690
# 70      GasA         Ex           Y      SBrkr         768         756
# 78      GasA         TA           Y      SBrkr        1253           0
# 80      GasA         Ex           Y      SBrkr         779         640
# 81      GasA         TA           Y      SBrkr        1083           0
# 89      GasA         TA           Y      SBrkr        2898           0
# 91      GasA         Fa           Y      SBrkr         833         833
# 96      GasA         Gd           Y      SBrkr        2014           0
# 100     GasA         TA           Y      SBrkr        1178           0
# 101     GasA         TA           Y      SBrkr        2515           0
# 112     GasA         Fa           Y      SBrkr        1320           0
# 113     GasA         TA           Y      SBrkr        1687           0
# 124     GasA         Ex           Y      SBrkr        1217           0
# 127     GasA         Fa           Y      SBrkr        1040           0
# 137     GasA         Gd           Y      SBrkr        1182         800
# 141     GasA         Ex           Y      SBrkr        1096           0
# 145     GasA         Gd           Y      SBrkr        1483           0
# 151     GasA         Ex           Y      SBrkr         975         780
# 157     GasA         Ex           Y      SBrkr        1375         862
# 158     GasA         Ex           Y      SBrkr         774         656
# 170     GasA         Ex           Y      SBrkr        1364        1319
# 176     GasA         Ex           N      SBrkr         845           0
# 196     GasA         TA           Y      SBrkr        1032           0
# 205     GasA         Gd           Y      SBrkr        1489           0
# 214     GasA         Fa           Y      SBrkr        1188           0
# 220     GasA         Ex           Y      SBrkr        1358           0
# 221     GasA         Ex           Y      SBrkr        1533         639
# 229     GasA         TA           Y      SBrkr         530         462
# 232     GasA         Gd           Y      SBrkr         880         428
# 240     GasA         Gd           Y      SBrkr         680         790
# 247     GasA         TA           Y      SBrkr        1332         192
# 248     GasA         TA           Y      SBrkr        1445           0
# 250     GasA         Ex           Y      SBrkr        1325           0
# 254     GasA         TA           Y      SBrkr        1006           0
# 264     GasA         Ex           Y      SBrkr        1072         976
# ...      ...        ...         ...        ...         ...         ...
# 2658    GasA         Ex           Y      SBrkr         892         783
# 2662    GasA         Ex           Y      SBrkr        1004           0
# 2663    GasA         Ex           Y      SBrkr         833           0
# 2671    GasA         Gd           Y      SBrkr        1437           0
# 2690    GasA         TA           N      FuseA        1160         908
# ...
# 137            Y           400            112               0           0
# 141            Y           240             32               0           0
# 145            Y           496              0               0           0
# 151            Y           502             60               0           0
# 157            Y           305             24               0           0
# 158            Y           180              0               0           0
# 170            Y           237            251               0           0
# 176            N           186              0               0           0
# 196            Y             0              0               0           0
# 205            Y             0              0               0           0
# 214            Y             0              0               0           0
# 220            Y            68            166               0           0
# 221            Y           162            153               0           0
# 229            Y           112             97               0           0
# 232            Y             0              0             117           0
# 240            Y           232             63               0           0
# 247            Y           268              0               0           0
# 248            Y           180              0               0           0
# 250            Y             0             42               0           0
# 254            Y             0             24               0           0
# 264            Y             0             48               0           0
# ...          ...           ...            ...             ...         ...
# 2658           Y             0            103               0           0
# 2662           Y             0              0               0           0
# 2663           Y             0              0               0           0
# 2671           Y           304              0               0           0
# 2690           Y             0              0              60           0
# 2699           Y           586            236               0           0
# 2703           Y           225              0              84           0
# 2704           Y             0              0               0           0
# 2708           Y           264             75             291           0
# 2717           Y           320             54               0           0
# 2728           Y           143             20               0           0
# 2729           Y           143             20               0           0
# 2730           Y             0            204               0           0
# 2742           Y           171              0               0           0
# 2746           Y           168            127               0           0
# 2747           Y             0              0               0           0
# 2752           Y            36             82               0           0
# 2764           Y             0              0               0           0
# 2769           Y             0              0               0           0
# 2776           Y             0              0             248           0
# 2791           Y           164              0               0           0
# 2796           Y             0             42               0           0
# 2797           Y           312              0               0           0
# 2818           Y             0              0               0           0
# 2824           Y             0              0               0           0
# 2834           Y           144             85               0           0
# 2837           Y             0              0               0           0
# 2853           Y             0              0             180           0
# 2859           Y           200            144               0           0
# 2861           P             0             48               0           0
# 2865           N             0            144               0           0
# 2869           Y             0            217               0           0
# 2874           Y             0             69               0           0
# 2875           Y           292              0               0           0
# 2892           Y             0             54               0           0
# 2895           Y             0              0               0           0
# 2897           Y             0              0               0           0
# 2901           Y           120             96               0           0
# 2908           Y           140              0               0           0
# 2912           N             0             33               0           0
# 2926           Y           198             42               0           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 0                0          0      NA     NA           NA         0        4
# 13               0          0      NA     NA           NA         0        3
# 26               0          0      NA     NA         Shed       350       11
# 34               0          0      NA     NA           NA         0        1
# 35               0          0      NA     NA           NA         0       11
# 38               0          0      NA     NA           NA         0        7
# 57               0          0      NA  MnPrv           NA         0        6
# 70               0          0      NA     NA           NA         0        6
# 78               0          0      NA   GdWo           NA         0        5
# 80               0          0      NA     NA           NA         0        3
# 81               0          0      NA     NA           NA         0        7
# 89               0          0      NA     NA           NA         0        5
# 91               0          0      NA  MnPrv           NA         0        6
# 96               0          0      NA  MnPrv           NA         0        4
# 100             88          0      NA  MnPrv           NA         0        6
# 101              0          0      NA     NA           NA         0        3
# 112              0          0      NA     NA           NA         0        5
# 113              0          0      NA     NA           NA         0        6
# 124              0          0      NA  GdPrv           NA         0        6
# 127            180          0      NA  GdPrv           NA         0        7
# 137              0          0      NA     NA         Shed      1500        4
# 141              0          0      NA     NA           NA         0        3
# 145              0          0      NA     NA           NA         0        4
# 151              0          0      NA  GdPrv           NA         0        7
# 157              0          0      NA     NA         Shed      2500        2
# 158              0          0      NA     NA           NA         0        4
# 170            196          0      NA     NA           NA         0        6
# 176              0          0      NA     NA           NA         0        1
# 196              0          0      NA  MnPrv         Shed       500        7
# 205              0          0      NA     NA           NA         0        8
# 214              0          0      NA  MnPrv           NA         0        5
# 220              0          0      NA     NA           NA         0        6
# 221              0          0      NA     NA           NA         0        6
# 229              0          0      NA     NA           NA         0        7
# 232              0          0      NA     NA           NA         0        4
# 240              0          0      NA     NA         Shed       480        4
# 247              0          0      NA     NA           NA         0        4
# 248              0          0      NA  MnPrv           NA         0        8
# 250              0          0      NA     NA           NA         0        7
# 254              0          0      NA     NA           NA         0        7
# 264            180          0      NA     NA           NA         0        8
# ...            ...        ...     ...    ...          ...       ...      ...
# 2658             0          0      NA     NA           NA         0        6
# 2662             0          0      NA     NA         Shed       700        3
# 2663             0          0      NA  MnPrv           NA         0        3
# 2671             0          0      NA     NA           NA         0       11
# 2690             0          0      NA     NA           NA         0        5
# 2699             0        738      Gd  GdPrv           NA         0        8
# 2703             0          0      NA     NA           NA         0        3
# 2704             0          0      NA     NA           NA         0        6
# 2708             0          0      NA     NA           NA         0        5
# 2717             0          0      NA     NA           NA         0        7
# 2728             0          0      NA     NA           NA         0        5
# 2729             0          0      NA     NA           NA         0        9
# 2730             0          0      NA     NA           NA         0        7
# 2742             0          0      NA  MnPrv           NA         0        5
# 2746             0          0      NA     NA           NA         0        2
# 2747             0          0      NA     NA           NA         0        8
# 2752             0          0      NA     NA           NA         0        6
# 2764             0          0      NA   GdWo           NA         0       10
# 2769             0          0      NA  MnPrv           NA         0        9
# 2776             0          0      NA     NA           NA         0        7
# 2791             0          0      NA     NA           NA         0        5
# 2796             0          0      NA  MnPrv           NA         0       11
# 2797             0          0      NA     NA           NA         0       10
# 2818           166          0      NA     NA           NA         0        3
# 2824             0          0      NA     NA           NA         0        1
# 2834             0          0      NA  GdPrv           NA         0        5
# 2837             0          0      NA     NA           NA         0        6
# 2853             0          0      NA     NA           NA         0        7
# 2859             0          0      NA  GdPrv           NA         0        7
# 2861             0          0      NA     NA           NA         0        6
# 2865             0          0      NA     NA           NA         0        6
# 2869             0          0      NA     NA           NA         0        6
# 2874             0          0      NA     NA           NA         0        4
# 2875             0          0      NA     NA           NA         0       11
# 2892           140          0      NA     NA           NA         0        6
# 2895             0          0      NA   GdWo           NA         0        4
# 2897             0          0      NA     NA           NA         0        4
# 2901             0          0      NA     NA           NA         0        5
# 2908             0          0      NA     NA           NA         0        5
# 2912             0          0      NA     NA           NA         0        6
# 2926             0          0      NA     NA           NA         0        6
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 0        2009       WD          Normal   236000.0
# 13       2009       WD          Normal    82500.0
# 26       2009       WD          Normal   200000.0
# 34       2008       WD          Normal   103000.0
# 35       2006       WD          Normal   230000.0
# 38       2007       WD          Normal   219500.0
# 57       2006       WD          Normal   137000.0
# 70       2006       WD          Normal   166000.0
# 78       2008       WD          Normal   157000.0
# 80       2009       WD          Normal   184100.0
# 81       2006       WD          Normal   172000.0
# 89       2008       COD        Abnorml   287000.0
# 91       2008       WD          Normal   161000.0
# 96       2009       WD          Normal   275000.0
# 100      2007       WD          Normal   135000.0
# 101      2007       WD          Alloca   200624.0
# 112      2009       WD          Normal   172500.0
# 113      2010       WD          Normal   160000.0
# 124      2009       WD          Normal   173000.0
# 127      2006       WD          Normal   160500.0
# 137      2009       WD          Normal   208000.0
# 141      2006       WD         Abnorml   138800.0
# 145      2010       WD          Normal   270000.0
# 151      2009       WD          Normal   235000.0
# 157      2009       WD          Normal   204000.0
# 158      2010       WD          Normal   180000.0
# 170      2008       WD          Normal   290000.0
# 176      2009       WD          Normal    84000.0
# 196      2007       WD          Normal   148000.0
# 205      2009       WD          Normal   185750.0
# 214      2010       COD        Abnorml   142000.0
# 220      2006       WD          Normal   220000.0
# 221      2008       WD          Normal   291000.0
# 229      2007       WD          Normal   106500.0
# 232      2008       WD          Normal   120000.0
# 240      2009       WD          Normal   185000.0
# 247      2010       WD          Normal   260000.0
# 248      2009       WD          Normal   158000.0
# 250      2007       WD          Normal   216000.0
# 254      2008       WD          Normal    80000.0
# 264      2007       WD          Normal   301000.0
# ...       ...       ...            ...        ...
# 2658     2009       WD          Normal        NaN
# 2662     2010       WD          Normal        NaN
# 2663     2009       WD          Normal        NaN
# 2671     2006       WD          Normal        NaN
# 2690     2010       WD          Normal        NaN
# 2699     2006       WD          Alloca        NaN
# 2703     2007       WD          Normal        NaN
# 2704     2006       WD          Normal        NaN
# 2708     2007       WD          Normal        NaN
# 2717     2006       WD          Normal        NaN
# 2728     2008       WD          Normal        NaN
# 2729     2006       WD          Normal        NaN
# 2730     2008       WD          Normal        NaN
# 2742     2009       Oth         Family        NaN
# 2746     2006       WD          Normal        NaN
# 2747     2007       WD          Normal        NaN
# 2752     2008       WD          Normal        NaN
# 2764     2008       WD          Normal        NaN
# 2769     2008       WD         Abnorml        NaN
# 2776     2009       WD          Normal        NaN
# 2791     2007       WD          Normal        NaN
# 2796     2006       WD          Normal        NaN
# 2797     2009       WD          Normal        NaN
# 2818     2010       WD          Normal        NaN
# 2824     2007       WD          Normal        NaN
# 2834     2007       WD          Normal        NaN
# 2837     2007       WD          Normal        NaN
# 2853     2008       WD          Family        NaN
# 2859     2009       WD          Normal        NaN
# 2861     2008       WD          Normal        NaN
# 2865     2010       COD         Normal        NaN
# 2869     2008       WD          Normal        NaN
# 2874     2010       WD          Normal        NaN
# 2875     2008       WD          Normal        NaN
# 2892     2010       WD          Normal        NaN
# 2895     2006       WD         Abnorml        NaN
# 2897     2009       WD          Normal        NaN
# 2901     2010       WD          Normal        NaN
# 2908     2009       WD          Normal        NaN
# 2912     2009       WD          Normal        NaN
# 2926     2006       WD          Normal        NaN
#
# [490 rows x 82 columns]

# %%
# Assume NaN Lot Frontage means not connected to street
df.loc[df[df['Lot Frontage'].isna()].index, 'Lot Frontage'] = 0.

# %%
# Remove houses with size above 4000 SF as recommended in the documentation
print(df.shape)
df.drop(index=df_tr[df_tr['Gr Liv Area']>4000.].index, inplace=True)
print(df.shape)
# Out:
# (2929, 82)
# (2925, 82)

# %% [markdown]
# # Explore cleaned data

# %%
df[continuous_cols].hist(figsize=(20, 20), bins=50)
plt.show()

# %%
df[discrete_cols].hist(figsize=(20, 20), bins=50)
plt.show()

# %%
fig, axes = plt.subplots(nrows=6, ncols=4, figsize=(20,20))
for i, nc in enumerate(nominal_cols[1:]):
    df[nc].value_counts().plot(kind='barh', ax=axes[int(i/4), i%4], title=nc)
plt.show()

# %%
fig, axes = plt.subplots(nrows=6, ncols=4, figsize=(20,20))
for i, oc in enumerate(ordinal_cols):
    df[oc].value_counts().plot(kind='barh', ax=axes[int(i/4), i%4], title=oc)
plt.show()

# %% [markdown]
# # Relationship between feature and target

# %%
df_tr = df[~df['SalePrice'].isna()]
print(df_tr.shape)
df_tr.head()
# Out:
# (2425, 82)
#    Order        PID MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    484  528275070          60        RL           0.0      8795   Pave
# 1   2586  535305120          20        RL          75.0     10170   Pave
# 2   2289  923228250         160        RM          21.0      2001   Pave
# 3    142  535152150          20        RL          70.0     10552   Pave
# 4   2042  903475060         190        RM          60.0     10120   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0    NA       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 1    NA       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 2    NA       Reg          Lvl    AllPub     Inside        Gtl      MeadowV
# 3    NA       IR1          Lvl    AllPub     Inside        Gtl        NAmes
# 4    NA       IR1          Bnk    AllPub     Inside        Gtl      OldTown
#
#   Condition 1 Condition 2 Bldg Type House Style Overall Qual Overall Cond  \
# 0        Norm        Norm      1Fam      2Story            7            5
# 1        Norm        Norm      1Fam      1Story            6            6
# 2        Norm        Norm     Twnhs      2Story            4            5
# 3        Norm        Norm      1Fam      1Story            5            5
# 4       Feedr        Norm    2fmCon      2.5Unf            7            4
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        2000            2000      Gable   CompShg      VinylSd      VinylSd
# 1        1951            1951        Hip   CompShg      Wd Sdng      Wd Sdng
# 2        1970            1970      Gable   CompShg      CemntBd      CmentBd
# 3        1959            1959        Hip   CompShg      BrkFace      BrkFace
# 4        1910            1950        Hip   CompShg      Wd Sdng      Wd Sdng
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         Gd         TA      PConc        Gd
# 1      BrkFace         522.0         TA         TA     CBlock        TA
# 2      BrkFace          80.0         TA         TA     CBlock        TA
# 3         None           0.0         TA         TA     CBlock        TA
# 4         None           0.0         Fa         TA     CBlock        TA
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         300.0            Unf
# 1        TA            No            Unf           0.0            Unf
# 2        TA            No            Unf           0.0            Unf
# 3        TA            No            Rec        1018.0            Unf
# 4        TA            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        652.0          952.0    GasA         Ex           Y
# 1           0.0        216.0          216.0    GasA         TA           Y
# 2           0.0        546.0          546.0    GasA         Fa           Y
# 3           0.0        380.0         1398.0    GasA         Gd           Y
# 4           0.0        925.0          925.0    GasA         TA           N
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         980        1276                0         2256
# 1      SBrkr        1575           0                0         1575
# 2      SBrkr         546         546                0         1092
# 3      SBrkr        1700           0                0         1700
# 4      FuseF         964         925                0         1889
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          1              4
# 1               0               0          1          1              2
# 2               0               0          1          1              3
# 3               0               1          1          1              4
# 4               0               0          1          1              4
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              8        Typ           1
# 1              1           Gd              5        Typ           1
# 2              1           TA              6        Typ           0
# 3              1           Gd              6        Typ           1
# 4              2           TA              9        Typ           1
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           TA     BuiltIn           2000           Fin            2
# 1           Gd      Attchd           1951           Unf            2
# 2           NA      Attchd           1970           Unf            1
# 3           Gd      Attchd           1959           RFn            2
# 4           Gd      Detchd           1960           Unf            1
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        554.0          TA          TA           Y           224
# 1        400.0          TA          TA           Y             0
# 2        286.0          TA          TA           Y             0
# 3        447.0          TA          TA           Y             0
# 4        308.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             54               0           0             0          0      NA
# 1              0               0           0             0          0      NA
# 2              0               0           0             0          0      NA
# 3             38               0           0             0          0      NA
# 4              0             264           0             0          0      NA
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  \
# 0     NA           NA         0        4     2009       WD          Normal
# 1     NA           NA         0        6     2006       WD          Normal
# 2     NA           NA         0        1     2007       WD          Normal
# 3     NA           NA         0        4     2010       WD          Normal
# 4  MnPrv           NA         0        1     2007       WD          Normal
#
#    SalePrice
# 0   236000.0
# 1   155000.0
# 2    75000.0
# 3   165500.0
# 4   122000.0

# %%
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20,20))
for i, cc in enumerate(continuous_cols):
    df_tr.plot.scatter(x=cc, y='SalePrice', ax=axes[int(i/4), i%4])
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20,20))
for i, dc in enumerate(discrete_cols):
    df_tr.plot.scatter(x=dc, y='SalePrice', ax=axes[int(i/4), i%4])
plt.show()

# %%
# discrete cols excluding years and order
discrete_cols2 = [
    'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces',
    'Garage Cars', 'Mo Sold', 'Yr Sold']

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20,20))
for i, dc in enumerate(discrete_cols2):
    df_tr[[dc, 'SalePrice']].boxplot(by=dc, ax=axes[int(i/4), i%4])
plt.show()

# %%
fig, axes = plt.subplots(nrows=6, ncols=4, figsize=(20,35))
for i, col in enumerate(nominal_cols[1:]):
    df_tr[[col, 'SalePrice']].boxplot(by=col, ax=axes[int(i/4), i%4])
plt.show()

# %%
fig, axes = plt.subplots(nrows=6, ncols=4, figsize=(20,35))
for i, col in enumerate(ordinal_cols):
    df_tr[[col, 'SalePrice']].boxplot(by=col, ax=axes[int(i/4), i%4])
plt.show()

# %% [markdown]
# # Save clean data

# %%
# drop Order column and keep PID for reference 
df.drop(columns=['Order'], inplace=True)

# %%
df.to_csv('house-prices-clean.csv', index=False)
